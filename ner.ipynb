# %%
import spacy
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------------------- -------------- 8.1/12.8 MB 41.8 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 35.8 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 30.9 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
df = pd.read_csv("processed_dataset.csv", low_memory=False)
df = df[['clean_post', 'subreddit']].dropna()

nlp = spacy.load("en_core_web_sm")

# %%
def extract_named_entities(text):
    doc = nlp(text)
    entities = [ent.text for ent in doc.ents]  
    return " ".join(entities)

# %%
df_sample = df[:10]

# %%
entities_list = df_sample['clean_post'].apply(extract_named_entities).tolist()
entities_list
# Out:
# ['',
#  'johns google yesterday first ps several thousand',
#  '9194049233 15',
#  '',
#  'grad school physics branching three months 5',
#  '',
#  'können einem bedarf vorfeld gedanken über zu messen',
#  '7k 1k day',
#  '',
#  'ga 3 days google google one']

# %%
chunk_size = 1000  
num_chunks = len(df) // chunk_size + 1

all_entities = []

for i in range(num_chunks):
    print(f"Procesando bloque {i+1} de {num_chunks}")
    df_chunk = df[i * chunk_size:(i + 1) * chunk_size]
    entities_chunk = df_chunk['clean_post'].apply(extract_named_entities).tolist()
    all_entities.extend(entities_chunk)
# Out:
# Procesando bloque 1 de 273
# Procesando bloque 2 de 273
# Procesando bloque 3 de 273
# Procesando bloque 4 de 273
# Procesando bloque 5 de 273
# Procesando bloque 6 de 273
# Procesando bloque 7 de 273
# Procesando bloque 8 de 273
# Procesando bloque 9 de 273
# Procesando bloque 10 de 273
# Procesando bloque 11 de 273
# Procesando bloque 12 de 273
# Procesando bloque 13 de 273
# Procesando bloque 14 de 273
# Procesando bloque 15 de 273
# Procesando bloque 16 de 273
# Procesando bloque 17 de 273
# Procesando bloque 18 de 273
# Procesando bloque 19 de 273
# Procesando bloque 20 de 273
# Procesando bloque 21 de 273
# Procesando bloque 22 de 273
# Procesando bloque 23 de 273
# Procesando bloque 24 de 273
# Procesando bloque 25 de 273
# Procesando bloque 26 de 273
# Procesando bloque 27 de 273
# Procesando bloque 28 de 273
# Procesando bloque 29 de 273
# Procesando bloque 30 de 273
# Procesando bloque 31 de 273
# Procesando bloque 32 de 273
# Procesando bloque 33 de 273
# Procesando bloque 34 de 273
# Procesando bloque 35 de 273
# Procesando bloque 36 de 273
# Procesando bloque 37 de 273
# Procesando bloque 38 de 273
# Procesando bloque 39 de 273
# Procesando bloque 40 de 273
# Procesando bloque 41 de 273
# Procesando bloque 42 de 273
# Procesando bloque 43 de 273
# Procesando bloque 44 de 273
# Procesando bloque 45 de 273
# Procesando bloque 46 de 273
# Procesando bloque 47 de 273
# Procesando bloque 48 de 273
# Procesando bloque 49 de 273
# Procesando bloque 50 de 273
# Procesando bloque 51 de 273
# Procesando bloque 52 de 273
# Procesando bloque 53 de 273
# Procesando bloque 54 de 273
# Procesando bloque 55 de 273
# Procesando bloque 56 de 273
# Procesando bloque 57 de 273
# Procesando bloque 58 de 273
# Procesando bloque 59 de 273
# Procesando bloque 60 de 273
# Procesando bloque 61 de 273
# Procesando bloque 62 de 273
# Procesando bloque 63 de 273
# Procesando bloque 64 de 273
# Procesando bloque 65 de 273
# Procesando bloque 66 de 273
# Procesando bloque 67 de 273
# Procesando bloque 68 de 273
# Procesando bloque 69 de 273
# Procesando bloque 70 de 273
# Procesando bloque 71 de 273
# Procesando bloque 72 de 273
# Procesando bloque 73 de 273
# Procesando bloque 74 de 273
# Procesando bloque 75 de 273
# Procesando bloque 76 de 273
# Procesando bloque 77 de 273
# Procesando bloque 78 de 273
# Procesando bloque 79 de 273
# Procesando bloque 80 de 273
# Procesando bloque 81 de 273
# Procesando bloque 82 de 273
# Procesando bloque 83 de 273
# Procesando bloque 84 de 273
# Procesando bloque 85 de 273
# Procesando bloque 86 de 273
# Procesando bloque 87 de 273
# Procesando bloque 88 de 273
# Procesando bloque 89 de 273
# Procesando bloque 90 de 273
# Procesando bloque 91 de 273
# Procesando bloque 92 de 273
# Procesando bloque 93 de 273
# Procesando bloque 94 de 273
# Procesando bloque 95 de 273
# Procesando bloque 96 de 273
# Procesando bloque 97 de 273
# Procesando bloque 98 de 273
# Procesando bloque 99 de 273
# Procesando bloque 100 de 273
# Procesando bloque 101 de 273
# Procesando bloque 102 de 273
# Procesando bloque 103 de 273
# Procesando bloque 104 de 273
# Procesando bloque 105 de 273
# Procesando bloque 106 de 273
# Procesando bloque 107 de 273
# Procesando bloque 108 de 273
# Procesando bloque 109 de 273
# Procesando bloque 110 de 273
# Procesando bloque 111 de 273
# Procesando bloque 112 de 273
# Procesando bloque 113 de 273
# Procesando bloque 114 de 273
# Procesando bloque 115 de 273
# Procesando bloque 116 de 273
# Procesando bloque 117 de 273
# Procesando bloque 118 de 273
# Procesando bloque 119 de 273
# Procesando bloque 120 de 273
# Procesando bloque 121 de 273
# Procesando bloque 122 de 273
# Procesando bloque 123 de 273
# Procesando bloque 124 de 273
# Procesando bloque 125 de 273
# Procesando bloque 126 de 273
# Procesando bloque 127 de 273
# Procesando bloque 128 de 273
# Procesando bloque 129 de 273
# Procesando bloque 130 de 273
# Procesando bloque 131 de 273
# Procesando bloque 132 de 273
# Procesando bloque 133 de 273
# Procesando bloque 134 de 273
# Procesando bloque 135 de 273
# Procesando bloque 136 de 273
# Procesando bloque 137 de 273
# Procesando bloque 138 de 273
# Procesando bloque 139 de 273
# Procesando bloque 140 de 273
# Procesando bloque 141 de 273
# Procesando bloque 142 de 273
# Procesando bloque 143 de 273
# Procesando bloque 144 de 273
# Procesando bloque 145 de 273
# Procesando bloque 146 de 273
# Procesando bloque 147 de 273
# Procesando bloque 148 de 273
# Procesando bloque 149 de 273
# Procesando bloque 150 de 273
# Procesando bloque 151 de 273
# Procesando bloque 152 de 273
# Procesando bloque 153 de 273
# Procesando bloque 154 de 273
# Procesando bloque 155 de 273
# Procesando bloque 156 de 273
# Procesando bloque 157 de 273
# Procesando bloque 158 de 273
# Procesando bloque 159 de 273
# Procesando bloque 160 de 273
# Procesando bloque 161 de 273
# Procesando bloque 162 de 273
# Procesando bloque 163 de 273
# Procesando bloque 164 de 273
# Procesando bloque 165 de 273
# Procesando bloque 166 de 273
# Procesando bloque 167 de 273
# Procesando bloque 168 de 273
# Procesando bloque 169 de 273
# Procesando bloque 170 de 273
# Procesando bloque 171 de 273
# Procesando bloque 172 de 273
# Procesando bloque 173 de 273
# Procesando bloque 174 de 273
# Procesando bloque 175 de 273
# Procesando bloque 176 de 273
# Procesando bloque 177 de 273
# Procesando bloque 178 de 273
# Procesando bloque 179 de 273
# Procesando bloque 180 de 273
# Procesando bloque 181 de 273
# Procesando bloque 182 de 273
# Procesando bloque 183 de 273
# Procesando bloque 184 de 273
# Procesando bloque 185 de 273
# Procesando bloque 186 de 273
# Procesando bloque 187 de 273
# Procesando bloque 188 de 273
# Procesando bloque 189 de 273
# Procesando bloque 190 de 273
# Procesando bloque 191 de 273
# Procesando bloque 192 de 273
# Procesando bloque 193 de 273
# Procesando bloque 194 de 273
# Procesando bloque 195 de 273
# Procesando bloque 196 de 273
# Procesando bloque 197 de 273
# Procesando bloque 198 de 273
# Procesando bloque 199 de 273
# Procesando bloque 200 de 273
# Procesando bloque 201 de 273
# Procesando bloque 202 de 273
# Procesando bloque 203 de 273
# Procesando bloque 204 de 273
# Procesando bloque 205 de 273
# Procesando bloque 206 de 273
# Procesando bloque 207 de 273
# Procesando bloque 208 de 273
# Procesando bloque 209 de 273
# Procesando bloque 210 de 273
# Procesando bloque 211 de 273
# Procesando bloque 212 de 273
# Procesando bloque 213 de 273
# Procesando bloque 214 de 273
# Procesando bloque 215 de 273
# Procesando bloque 216 de 273
# Procesando bloque 217 de 273
# Procesando bloque 218 de 273
# Procesando bloque 219 de 273
# Procesando bloque 220 de 273
# Procesando bloque 221 de 273
# Procesando bloque 222 de 273
# Procesando bloque 223 de 273
# Procesando bloque 224 de 273
# Procesando bloque 225 de 273
# Procesando bloque 226 de 273
# Procesando bloque 227 de 273
# Procesando bloque 228 de 273
# Procesando bloque 229 de 273
# Procesando bloque 230 de 273
# Procesando bloque 231 de 273
# Procesando bloque 232 de 273
# Procesando bloque 233 de 273
# Procesando bloque 234 de 273
# Procesando bloque 235 de 273
# Procesando bloque 236 de 273
# Procesando bloque 237 de 273
# Procesando bloque 238 de 273
# Procesando bloque 239 de 273
# Procesando bloque 240 de 273
# Procesando bloque 241 de 273
# Procesando bloque 242 de 273
# Procesando bloque 243 de 273
# Procesando bloque 244 de 273
# Procesando bloque 245 de 273
# Procesando bloque 246 de 273
# Procesando bloque 247 de 273
# Procesando bloque 248 de 273
# Procesando bloque 249 de 273
# Procesando bloque 250 de 273
# Procesando bloque 251 de 273
# Procesando bloque 252 de 273
# Procesando bloque 253 de 273
# Procesando bloque 254 de 273
# Procesando bloque 255 de 273
# Procesando bloque 256 de 273
# Procesando bloque 257 de 273
# Procesando bloque 258 de 273
# Procesando bloque 259 de 273
# Procesando bloque 260 de 273
# Procesando bloque 261 de 273
# Procesando bloque 262 de 273
# Procesando bloque 263 de 273
# Procesando bloque 264 de 273
# Procesando bloque 265 de 273
# Procesando bloque 266 de 273
# Procesando bloque 267 de 273
# Procesando bloque 268 de 273
# Procesando bloque 269 de 273
# Procesando bloque 270 de 273
# Procesando bloque 271 de 273
# Procesando bloque 272 de 273
# Procesando bloque 273 de 273

# %%
all_entities
# Out:
# ['',
#  'johns google yesterday first ps several thousand',
#  '9194049233 15',
#  '',
#  'grad school physics branching three months 5',
#  '',
#  'können einem bedarf vorfeld gedanken über zu messen',
#  '7k 1k day',
#  '',
#  'ga 3 days google google one',
#  'zero',
#  '',
#  '',
#  'google one',
#  'russian spanish',
#  'spss',
#  '',
#  '',
#  '2009',
#  'first three month 7609 month march 2011 104716 2010 89517 1698 april 2011 60989 2010 60188 133 may 2011 99639 2010 1340',
#  'google',
#  'one one ga second',
#  '',
#  'first 1 2 3',
#  '',
#  'first 3',
#  'ga one',
#  '',
#  '',
#  '8 one 1 one 2 3 4 zero',
#  '',
#  '',
#  'ga ga',
#  '',
#  'joseph tennessee one',
#  'ga',
#  '',
#  'two',
#  '',
#  '14k 301',
#  'ga 301 301 third',
#  'yahoo microsoft google google yahoo 1 2 yahoo cpc yahoo 3 microsoft google 1 2 yahoo cpc microsoft camplign 3 microsoft',
#  '',
#  'one',
#  'cms',
#  'every month google',
#  'bitchen wolframalpha 09 064757 2012',
#  'today 79 35 48 4554',
#  '',
#  'first year ibm',
#  '6 week two 1577366 9371 178 9371 1577366 2958 019 ga ga 20000 1 2 3x 3 6 12 5 google 4 5 days',
#  '25k year london',
#  '',
#  'india',
#  '',
#  'two',
#  '100',
#  '',
#  'ga friday google conversion university one 1234 1199 129 5 san jose city california 1234 dd44 1199 1 ga googleanalyticscomgajs var documentgetelementsbytagnamescript0 ltscriptgt ltheadgt',
#  'every couple days first month past year benchmark see month later',
#  '370 november 2',
#  '',
#  'monthly three monthly one',
#  'ga',
#  'google',
#  '2 1 2 quarterly',
#  'newbie ga one',
#  '50',
#  'ga first 1 4 firstly ga 4 2 ga 3',
#  '',
#  '1015 minutes',
#  '1credit one 5 hour',
#  '',
#  'devs one datalayer amp container devs one',
#  'one first denver',
#  'minneapolisst paul',
#  '',
#  '5050 million apps within ps',
#  'jump roof tomorrow',
#  '100 yahoo ga ios6',
#  '',
#  'ga datalayer transactionid 1458078 6697 501 000 31799 1699 1 31803 daily 35 2499 2 0 1 datalayer transactionid 1458078 6697 501 000 31799 1699 1 31803 daily 35 2499 2 0 1',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  'ga past two days less three days old 80 14 days old',
#  '',
#  'newbie',
#  '',
#  '',
#  'ugotmitch87 ga 1819 1189 ga yahoo 1821 2 1519 one ga',
#  '',
#  'google google google google',
#  '',
#  'past couple months monday yesterday one last years today monday yesterday yesterday period taken morning',
#  '',
#  'two',
#  'first 71xxxxxxx',
#  'next year 2015 2 years',
#  'blog highlights technology',
#  'ga',
#  'maybe hours',
#  '400500 0 35',
#  'google',
#  'ga',
#  'one long years 2',
#  '',
#  '',
#  '',
#  'thousands',
#  'two years first year two',
#  '',
#  '',
#  'google',
#  'ga 1st ga edit1 ga roughly 20 weeks ago ga',
#  '30 30 40',
#  '',
#  'ga',
#  'last 2 years',
#  '',
#  'second',
#  'ga documentgetelementsbytagnamescript0',
#  '',
#  'mobile apps devs',
#  '1 2 3 4',
#  'google',
#  'ga',
#  '',
#  'google cms',
#  '17',
#  '100 0',
#  'vba',
#  'google 1 2',
#  '',
#  '',
#  'google osx',
#  'ga second first second',
#  '',
#  'google karansphotostk ps',
#  'wp plugins',
#  'one first second utmcontentp411432',
#  'one cms one',
#  '',
#  '208',
#  '',
#  '',
#  'next year',
#  'one couple days roughly 10k one 150',
#  '',
#  '11 google',
#  'google past couple weeks india english india',
#  'tracking year ago',
#  'google 9 days 10 46 287 5050 25 9 days 40 2500',
#  'philadelphia ga css html php java',
#  '',
#  'importance mobile',
#  'hour',
#  'ga first today 500 ga 32 ga two woke morning ga today 817',
#  'one 01 1',
#  '20 ga ga',
#  'google ga',
#  'december 2014 december gt40 past year approximately 5 million months nationwide vs sfasilicon valley salaries',
#  'saturday june 28 2014 30706 000 wednesday july 2 2014 63661 000 google ga 99 june 28',
#  '',
#  'accurate google google 100',
#  '',
#  'google',
#  'ga 3 1000 500 1 250 2 150 3 500',
#  'one ga google two google two 1 two 2',
#  '99 leave first month daily days later',
#  'ga',
#  '',
#  '10 ga',
#  '0 1',
#  '45 minutes',
#  '',
#  'two last week 250',
#  '',
#  'email many days weeks',
#  'two two',
#  '',
#  '',
#  'work national bank analytics department',
#  '10 09',
#  '',
#  'google nearly 9 months old weekly monthly google voice accountnumber',
#  '',
#  'karnik',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'hundreds iddealerlocator2 border0 first',
#  '',
#  '25 one 20 1 first 1 8 1 1 one',
#  'google',
#  '48266 287 48266 287 168 10944 287 10944 262 168 441 441',
#  '25 million several years 30 seconds 1 minute 5 minutes',
#  'today ga',
#  '',
#  'google',
#  'ga weekend days',
#  '',
#  '2 percent 10 percent',
#  '',
#  '',
#  '',
#  '',
#  'costperclick productionperclick one first days later',
#  'анализ конкурентов в сервисе возможностей',
#  'google',
#  '',
#  '',
#  'one first 1 2 two 1',
#  'ibm next two years 10 percent gartner smart machines 2014',
#  'first',
#  'google hundreds',
#  'one one two',
#  'third google monthly 3rd',
#  'daily next month microsoft dynamics crm',
#  'one',
#  'december spss years 6 years almost 25',
#  'today 500 100 mamodia today first cherian',
#  '1 ga ua123456781 ga ua123456783 2 ga universal ua901234561 1 one ga one one',
#  '10 one',
#  '',
#  'couple weeks ago',
#  'ga',
#  'google analyticstag',
#  '',
#  '1972 100 • english • • 35 years',
#  'one day 928 sec day 064s one',
#  '2 hours ago last checked nov 17 2014 21708 google ga',
#  'jan 1nov 17 90 days max',
#  '• english • • 35 years',
#  'one ga ga 95 5',
#  '',
#  'google',
#  'first',
#  '',
#  'one',
#  '1 third one nearly 7000 100 ga second first goal least 5 seconds ga 2',
#  'redshoes16 zero zeros',
#  'ga',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'google 2 2 ga ga',
#  'first 100 asu smu',
#  'yesterday ga',
#  'last days ga',
#  '4 years spss modeler',
#  'google ga',
#  'google second',
#  '2nd udecoy98',
#  'one 3 2session first 1user first ga ga',
#  '',
#  'ga',
#  'one state nyu one minor 2nd 3536 summer 2year',
#  '',
#  '',
#  'ga',
#  'acls pros cons',
#  '',
#  '75 50 one',
#  'thousands',
#  'google one',
#  'ga 093',
#  '',
#  'past 7 days first 80',
#  '',
#  '',
#  'three months',
#  'us write sql queries',
#  '',
#  'ga 45',
#  'french 6 25',
#  '',
#  'ga ga ga',
#  '100 russia edit2',
#  'ga',
#  '2007',
#  'past 10 months',
#  'kpi planning',
#  '',
#  'google academy ga',
#  'bianalytics association organization',
#  'first 11 prior years 90 12 last year 200k 1 zero last 6 months 4 1 month',
#  'one day 1000',
#  '',
#  'one midnight google 2 2',
#  'google hundred one two',
#  '28 monthly monthly zero 1 one first 2 google academy resources 3',
#  '',
#  '30 last 4 days 5',
#  'daily',
#  '',
#  'ga hundreds ga',
#  'first 30',
#  'matterhornio project management tool',
#  'last month previous month',
#  '',
#  'russian',
#  '',
#  'coop',
#  'ga ga ga 500 100 last 30 minutes last week 500 two days ga',
#  '7000 5',
#  'bachelor business commerce 15 years two one two 35 one',
#  'microsoft dynamics roughly 25 past year',
#  'first',
#  'google almost 50 brazil 10 brazil brazil',
#  'sunday super bowl 2015 new england today 630pm nfl gameday sunday super bowl nbc tv sunday super bowl nfl live broadcast seattle seahawks university phoenix stadium new england seattle today nfl nfl england nfl new england patriots vs seattle sunday sunday today today 2014 today first england 630 pm et date esp3 abc nbc cbsc cbs seattle nfl game watcespn new england first 2015 2014 first 2015 nfl new england patriots vs seattle sunday super bowl sunday 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015',
#  'cs cm',
#  'google 4 years ago 4 years',
#  'ilovevitalyinfo ilovevitalyinfo iskalkoru iskalkoru lombiaco lombiaco',
#  '2 1 1 canada 30 28 150 230 one',
#  '',
#  'ga ga 11 last 30 days 2 russia ga',
#  'right ill 32 first 1996 age 14 teen years today 100 one one',
#  'one',
#  'zanussi 50 million 150 uk 300 uk head first two 4 10 4000045000 annual',
#  'one 2013 2014 month leading start row monthly',
#  'two 3rd',
#  '0 google thousand impressions per month dozens 0 13 google 34 0 two',
#  '',
#  'one previous year',
#  'two',
#  'one',
#  'today las vegas',
#  'hundreds google organic',
#  '',
#  '',
#  'day months 100000 150000',
#  'first',
#  'one ga 2 1 300 2 200 3 1 300 2 200 3 1',
#  'english first',
#  'past 10 days february 10th exactly 24 hours almost minute 0000 2359 40',
#  'one two',
#  '',
#  'ga 2 ga',
#  'past year half ga ga ga',
#  'google',
#  'two 1 2 ga',
#  '2 first 1',
#  'british',
#  '',
#  'canada russia canada',
#  '2015',
#  'ga',
#  '18 months 98 marks',
#  'third',
#  '2',
#  'examplecom12345 ga',
#  'first',
#  'one ga one ga',
#  'google google',
#  'first 1 5k 42k 10 500 1k 1 3k',
#  'every day daily',
#  'ga',
#  'one google google',
#  '',
#  'roughly 100 cms devs',
#  '',
#  'ga toblah view',
#  '96 one 26',
#  '2016 arizona wp carey 16 month 9 month',
#  '672 897 162799 192 one',
#  '',
#  'one 200',
#  '',
#  'half ga ga last year',
#  'years first six second 8 minute 11',
#  '150 20 annually 50 85 20000 30000 annual 30 annual 95 annual 20year',
#  'friday',
#  'ga 9 one 220 9 0 9 first first 9 0',
#  '',
#  '',
#  '1 15 40 gt 15 30 40 percent',
#  'india',
#  '',
#  'four',
#  'google april 20th 1for1',
#  '',
#  '',
#  'firstly 60 20 16 40 5 3 4 months 5 month 5 last month',
#  '1000 500 50 google 5 50500 10',
#  'google ps temporary',
#  'ga',
#  '12 6 months 50 one day two seperate days 50',
#  '15 days',
#  'ga',
#  'one',
#  'gary keller',
#  '3 2 1 hours vs hours',
#  '2 abc123',
#  'google',
#  'ga one',
#  'google alexander holl 121watt google',
#  'monthly ga month month',
#  '1 2 2000 3 half 2000 ps',
#  '10 10 15 15 20 20 20 30 40',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '1 2 metric',
#  'toronto canada',
#  '',
#  'seo seo',
#  'thousands 45 minutes 3 minutes',
#  'quarter mile two',
#  'days ga',
#  'contrarian',
#  'çeti̇n 51 pastasından kimin büyük üzerindeki tartışma ettirdi değişen nihai anlaşmanın tarih olarak 30 nihai konusunda anlaşmaya varıldığı açıklandı anlaşmazlık konuları santrifüj ağır su reaktörlerinin durumu nükleer işbirliği yaptırımların kaldırılması sermaye faaliyetleri olarak 20 kabul 90 zenginleştirilmiş gereken çünkü nükleer kısmını nükleer yakıta dönüştürüldüğünü yapma niyetinin 10 bin adedi olan 19 bin 6 geçmemesi natanz çevrilmesi konularında sonrasında yapılacak nihai anlaşma 10 abd ab istiyordu tahran finans konseyi kararı gereğince ancak batı abd ab kalkmasını askıya alınmasını çünkü başkan devletlerin cesaretlendiği aktörleri peşinden sürükleyecek 2014 durumunda başkan obama ya destek verecekleri kabul de uluslararası konularda seslerini çok abd çıkmasının zor öngörülüyordu cumhuriyetçi senatörler arasında varılacak sadece başkan bobama lideri ayetullah ahamaney arasında bağlayan bir anlaşma olmaktan anlaşmanın geçerliliğinin kabul i̇stihbarat bakanı ysteinitz karşı askeri da dahil masada tehdidi göstergesi türki̇ye suudi arabistan yemen operasyonu ile nükleer arasında bağ var yemen karıştırma potansiyeli abd batı tarafından kabul gücünün arkasında ittifakı sadece değil küresel anlamda da varlığını kabul ettirdi bölgede yeni bölgesel güç olarak abd batı abd suriye arıyor abd dışişleri john kerry abd olarak siyasi değişim beşar etmek zorunda olacaklarını söylemesi suriye örgütün mevzilerine istihbarat değişen politikaların göstergesi 2012 beri abd kardeşleri kardeşlerin hem islam sadece suriye konusunda değil ya bakışında kalması konusunda ile de gizli olduğu ortaya rejimi değiştirmenin azından şimdilik abd için niyetleri batıya değil batı yanlısı olmayacaklar suudi arabistan katar rejiminin çöküşü kurtarmayacak çatışmaları bitirmeyecek daha kötü karşı soykırımı başlarken iki taraftan da uzak durmayı kimyasal silahların istenmeyen güçlerin geçecek olmasıdır abd suriye müdahalesi 60000 kendisi kara yanaşmazken avrupa da suriye kardeşleri desteklemesi suriye ’ de de ılımlı görüntüsü altında deki kürtlerin konusunda ki farklı da buna nihayet hem abd hem de bölgedeki karşı ataklarla kürdi̇stan planlari rafa mi kalkiyor dönüşümün yanısıra abd ile da değiştirebilir şii irak irak kürt konjonktür gerek kuzey deki kürtçülük hareketlerinin abd ile uzlaşan kürt yapılanmasına gelişmeler abd batı söylemleri aslında körfez oturan bu ilişkiler libya krizleri ile küresel dengeleri almanya ile i̇ran dışişleri bakanlarının temsilcisi katılırken abd olmak üzere devletlerle anlaşma ruhani şahsında konjonktür erdoğanvari görmek istediği liderliklerin hepsi birer birer giderken düşman olduğu liderler konumunu zayıflatıyor abd tarafından abd darbesi nin yardımı geçmesi erdoğan eksenine yanaşma kumpaslarla tutuklanan nın subay kendisine yeni bulma kabul ancak bu çabaların başarıya ulaşma şansı kabul anlaşmanın sonuçlarından biri de ilımlı karşısında bunun abd olmak üzere küresel güçler karakterli bunun süre kala türkiye seçimlerinden de bu yöndedir 13 türk dış aslında ne kadar sığ olduğu davutoğlu abd siyasi geleceğini kaybedeceğinin de farkında saflarda bulunması yeni arenada batı ile birlikte olarak davutoğlu akp hükümetinin nın yanında yer alma çabasının başarı da zaman tarafından kabul kişilik olarak çıkarsa temelli kesimleri desteklemesi politikaların mimarının abd batı tarafından bulunması zor gibi',
#  '',
#  '1660 first one 1014 second',
#  '',
#  '1 2 2014 ga one 1 half last year ga last year year year ga last year',
#  '20142018',
#  'first',
#  'one 404s 10',
#  'ga 20',
#  'gt100k',
#  'google 95 percent one',
#  'toronto',
#  'second khan',
#  '8020',
#  'ga ga',
#  'last week 5 2 2',
#  '',
#  '10x ga',
#  '',
#  '',
#  'google',
#  '',
#  '',
#  '',
#  'one ga',
#  '',
#  'google',
#  '',
#  'yesterday hundred 97 34',
#  'ga',
#  'ga cpc',
#  'zeros',
#  'first',
#  '',
#  'tens thousands',
#  'google last fall four five monthly monthly google three monthly monthly january february monthly google january february february google',
#  'ga one day ga early days',
#  'ga one day ga early days',
#  'later day day',
#  '',
#  '',
#  'google month april google april january january',
#  '',
#  '',
#  'hundreds thousands',
#  '',
#  '1 2',
#  '',
#  'ga 50 10 10 ga ga',
#  '5 1 examplecomcheckoutk1 2 examplecomcheckoutk1 3 examplecomcheckoutk1 4 examplecomcheckoutk1 ga 1 examplecomcheckoutk1 2 examplecomcheckoutk1 3 4 3rd 1',
#  'wp google gascrolleventsjsver42134',
#  'google 404 one',
#  '8590 85 770',
#  '',
#  '',
#  'ga 30k daily ga',
#  '',
#  '',
#  'google',
#  'germany italy 389000 germany sunday monday',
#  '',
#  '',
#  'newbie',
#  '',
#  'google',
#  'yesterday matter seconds 20 30 minutes second 100 first second 1 second 0',
#  'yesterday today 199 129',
#  '',
#  'ga one one',
#  '6 months 100',
#  '',
#  '',
#  'first daily ga opengraph metadata chart last 60 days vs last year',
#  '',
#  'one',
#  'geo america 10',
#  'dozen',
#  '1 2 one register webinar click one russian mon may 18 2015 300 pm 400 pm english tue may 19 2015 500 pm 600 pm gmt sabirovcom ps',
#  'urls identify mobile desktop',
#  '4 4 one ga one ga',
#  '5 years 1200 1050euros 1 30min 2 ga db third 3 4 5 6 ga ga four secretescapescom zaggoracom',
#  '',
#  'half half',
#  'minute',
#  'ga last 23 weeks cert tons 10 last 6 months 5 10',
#  '2 months 4 weeks first 647 macintosh info un google',
#  '',
#  '214 1990 2010 1990 2010 1990 2010',
#  'kickstarter',
#  '',
#  '',
#  'one every second day day week 1st day 35 2nd day 3rd 650 5th day 29 month two ago',
#  '',
#  '',
#  '2007 several years 3 years ago next fall 1 1 3 years',
#  'ga',
#  '',
#  'last 2 weeks dallas chicago 1 day',
#  '0',
#  'today 25',
#  'google',
#  'tatvic webinar today 3 pm second second 3',
#  '',
#  '',
#  '',
#  '',
#  '23 4',
#  'bro abc ga code xyz 90 10 1 xyz 2',
#  '500 2015 google',
#  'two',
#  '5',
#  'one',
#  '10 years google',
#  'ga 4050 2530 20 10 50',
#  'ga one ga',
#  'chicago',
#  'google british 69 87 30 postclick 42',
#  'work department sections',
#  '',
#  '7 7',
#  'five',
#  '123 4',
#  '22 86 one 22 86',
#  'summer three 3 first second third three 101101101012 10110110109102 202202202520 2022022025910920 985612618 98561269108',
#  '',
#  '',
#  'ga ga ga',
#  'ibm spss',
#  '7090 couple days',
#  'google hourly hourly google hourly 5 hour google',
#  'seo google 6995 month 3 99 month google weekly one',
#  '',
#  'google google',
#  '1 2 menuanotherexamplethankyouhtml',
#  '',
#  'gtm day',
#  '101',
#  '',
#  'ga 52 12 days first',
#  '30 seconds',
#  '25',
#  '',
#  'google',
#  'ga two minute hour past three days 1s fifteen 1 1s 2s one',
#  'ga ga 2 200000 400000',
#  'ga',
#  'second 10',
#  '',
#  '',
#  '2 weeks ago',
#  'kilometer io',
#  '',
#  '12 12 organically google',
#  'first second',
#  '',
#  '15 ga',
#  'hour ago second latin american',
#  'google ga ga',
#  '',
#  '',
#  '',
#  'zero google google',
#  'dong',
#  'six 60 95 uaxxx2 eli5style',
#  '',
#  'russia almost 100',
#  '100 google webmaster tools',
#  '',
#  'hundreds',
#  'google inc',
#  '',
#  'ga info ga android 1090 4 4s 1st',
#  'year',
#  'google',
#  'russia',
#  'one 1st',
#  '',
#  'google third',
#  'google mutlaka kullanmaları ücretsiz olarak ziyaret eden kişiler hakkında çok gördüğü buna çok özelliği ile henüz google kullanıyorsanız kayıt işlemini yapmalısınız hesap kullandığınız hesabınız ile giriş yapmanız gerekiyor analyticsgirişekranı giriş yaptıktan ekrandan google kayıt oluyorsunuz ekranda kaydol kaydolduktan çıkacak resimde gösterildiği gibi doldurabilirsiniz 11analytics google kabul edin sözleşmeyi de kabul kullanıyorsanız alan vardır yerini bilmiyorsanız biraz dikkatlice kodu sitenizde izlemek istediğiniz sayfada ltheadgt tagının ziyaret eden kişiler çeşitli google solunda bulunan menüleri kullanarak kullanan kişilerin ziyaret ettikleri telefon tablet gibi hatta görüntülendiği ekranın çok ziyaretçi kitlesi size kanalları kullanarak sitenizde ne çıkışı süre gibi arama motoru kullanarak kelimeleri kullanarak gibi detaylara da ulaşmanız google reklamlarını kullanıyorsanız buradan da kontrol i̇le si̇te google testin sonucunda varsa size siteniz google sitenizde ki çok alan canlı olarak gerçek zamanlı olarak sitenizde bulunan ziyaretçileri şansınız var analyticsgerçekzamanlı google kullanarak olan etkinlikleri de izlemeniz google kısımında bulunan sekmesine tıklayarak açılan sayfada yazan butona resimdeki la karşılaşacaksınız burada hazır sayfada hedefi google takip ederken görmek istediğiniz ismi belirleyin sayfayı izlemek için yazıp dilerseniz sayfa ziyaretleri atayabilirsiniz türünü sayfada süre ziyaret eden kişilerden ziyaret edenlerini de izleyebilirsiniz olarak da sitenizde ayarlamış olmanız gerekmekte ayarladıktan çalışmadığını kontrol edebilirsiniz siteleri artık zorunlu gelecekte satacağınız ürünleri siteniz yapacağınız gibi kararlarda en büyük yardımcılardan birisi biraz zaman harcayarak bazı şablonlar şablonları takip aldığınız',
#  'ga',
#  '',
#  'today 28day monthly',
#  '',
#  'one 124 391 543 ga 112 49 61 ga 3 5 two',
#  'ga 349 russian',
#  'ga',
#  '',
#  '',
#  '',
#  'three 3 6 3 15',
#  '',
#  'end week week thousands five years ago',
#  '1 2 3 1 2 3',
#  '1 2 3 1 2 3',
#  'darodarpricegbuttonsforyourwebsitemakemoneyonlineblackhatworthhulfingtonpostoo6oosocialsimplefreesharebuttonsbestseosolutionoffergooglsucksbestwebsitesawardscomsemalt economcoilovevitalycomruhumanorightswatchguardlinksmailikwebmastersnticrawlerorggetfreetrafficnowalivematrixeventtracking100dollarssuccessseovideosforyourbusinesscomyoupornforum 100dollarsseocom',
#  '2 weeks ago 50 100 bounce000000 100000000',
#  'third',
#  'one two',
#  '',
#  'google zero zero',
#  'one first',
#  '200',
#  'ga ga',
#  'hose 1 5 1 hose',
#  'last couple months first 90',
#  'last week ga months ago',
#  'last week 35 hundreds 3 last 6 months',
#  'one',
#  'ga ga 1 million bucks',
#  'google',
#  'ga google ga one',
#  'ga 100 80 80 20 one 400 100',
#  'ga ga google',
#  '',
#  'first',
#  'first',
#  '',
#  '',
#  '133 202',
#  '24h',
#  'first first google',
#  '4th quarter cy13 cy13',
#  '',
#  '',
#  'эти вещам рассказ о по 8минутную видеозапись',
#  'ga 2 ga',
#  'first builtin years one half monthly two 90 two',
#  'two',
#  '',
#  'end month ps moderators',
#  'brian clifton first europe google',
#  'ga three one 1 2 3',
#  'komoona daily',
#  '',
#  '3rd 3rd 2nd',
#  'today',
#  '',
#  'ga',
#  '',
#  '',
#  'two',
#  'ga',
#  '100',
#  '',
#  '',
#  '2000000 past month 2400000',
#  'hundreds',
#  '',
#  'ga ga',
#  'three months third one',
#  '11',
#  'wednesday noon today almost 300 google ga 5 20 week',
#  '',
#  'europe',
#  'years',
#  'google last week one yesterday yesterday ga google',
#  'weekly every week google daily google',
#  'today',
#  '3 one 500 two',
#  '',
#  'first',
#  'searchartkeywordtestpage1 ga',
#  'several months ago two half 15 50',
#  '190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 ppv transmissão 190 190 190 190 correia transmissão 1 dia 190 20 190 190 2 pelo 190 190 190 20 horas atrás minuto 190 190 190 3 hoje vamos 190 7 190 página 190 passam pela 190 242 globotvglobocomvrouseycorreiaufc19043 22 passam pela 190 2 190 08012015 1 1 190 190 4 190 190 jogo 190 190 190 1º hsbc arena rio de janeiro',
#  'long time ago august',
#  'ga',
#  '',
#  'ga',
#  'ga',
#  'around techniques hour',
#  'almost two months old one one one day 713 12 hundreds one google',
#  'info ga',
#  'google',
#  '',
#  'half',
#  '',
#  'ga ie',
#  '5060 1520 overnight couple months ago 40 60 24 5',
#  '',
#  'activating ga ga 10 40 hits day 450',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  'ga ga bannerclick banner',
#  'google one last month 50 250 250 2 one',
#  'uri gt',
#  'tomorrow two',
#  'ga',
#  'brian clifton first europe google',
#  '350€month ga',
#  'three',
#  'mark spam two',
#  'past year',
#  '',
#  'ga mydomaincom',
#  'google',
#  'nooverride1 one google',
#  'google yesterday evening ga 10001200 400',
#  'suddenly 25th july google',
#  '',
#  '',
#  '',
#  '',
#  'ga ga',
#  'google',
#  'ga 30 seconds one one',
#  '',
#  '7 years ago',
#  'ga',
#  '',
#  '',
#  'ga week ago ga 280 5 5 ga',
#  'ga devs ga ga',
#  'ga',
#  'monthly four six ga three',
#  'ga',
#  '3 ga ga ga',
#  '',
#  'half ga',
#  'ga',
#  'working ab test campaign week first 256 two',
#  'ga',
#  '',
#  '',
#  '',
#  'one 23k 173k',
#  'ga ga',
#  '828 1608',
#  'zero zero one google two google',
#  'brian clifton first europe google',
#  'three ga',
#  'yesterday 9 one 9 safari yesterday',
#  '',
#  '',
#  'one 300x250',
#  'google microsoft',
#  'today two xxxxx1 xxxxx38 one least 38 second',
#  'google',
#  '',
#  '4',
#  'ga',
#  '',
#  'urls yoursitecomservicesutmcontentsourcemail ga',
#  '100 two ga',
#  '3rd google',
#  '2 one 1 69',
#  'google analytics academy',
#  '',
#  '',
#  'ga',
#  '',
#  'time week week month month',
#  'ga',
#  'hundred 50',
#  'google',
#  '',
#  'google two ga 2',
#  'tuesday 6th 0 5 2',
#  '1 day first one 45 90 826 dutch',
#  'ga ga 3rd',
#  'ga ga ga',
#  'google 4586 last month 114k 12496 3693 3281 58 460 76488 178 37916',
#  'degree business management administration years master week two years two years',
#  '100 google',
#  '',
#  '',
#  '',
#  'securityprivacyetc browser',
#  '4 months last year google last years roughly 55000 6 weeks minute minute 5 minutes',
#  'ga',
#  'ga ga',
#  '',
#  'ga',
#  '4 3eo0000012usnam 4gb ram 17 5 minutes 13 100ish 111th less 8 hours 1',
#  'weeks 215',
#  'last year',
#  '',
#  'ga 10mmo 10mmo 10 one',
#  'weeks 2000 83',
#  '',
#  'one',
#  '404 third',
#  'first first',
#  '',
#  'tcsplitst0t1return jquerydocumentreadyfunction iftypeofurlfile 400 ga',
#  '',
#  'ga sometime next quarter',
#  'two 2',
#  'ga dsp sessions google dsp 10 300x250canbedifferent 10 one 10 ga one two dsp platform 320 3 ga',
#  'ga googleorganic 18 60',
#  'seo',
#  'last weeks around 50',
#  '',
#  'ga',
#  '',
#  '200 99 one 5 minutes',
#  '',
#  '60k 1000',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two days 100 1 403 403',
#  'ga ga ga ga',
#  '24 week',
#  '',
#  'november 4th ga 1000 ga ga 1 sec 0',
#  'daily',
#  '6',
#  '',
#  'info info google docs',
#  '',
#  'google matt cutts',
#  'google 1000 10',
#  '',
#  '3 months 4 sessions weekend 30s weekdays',
#  'two hundreds',
#  '',
#  'today friday 50 friday',
#  'nearly 100 404 google 404 two',
#  'years years daily past months',
#  'one google',
#  '2015',
#  'suffix 404',
#  '6 today ga',
#  '',
#  'weekly',
#  'ga',
#  'dialogtech google dialogtech',
#  '',
#  'third one',
#  'months seo',
#  '10',
#  '',
#  '',
#  'one 14223vcx5 google',
#  '4 years next 4 years last several years half',
#  'google ga ga ga',
#  'ga 50 ga ga 100 transactions month 150',
#  '',
#  '',
#  '',
#  '1 2 3',
#  '1 2 3',
#  '1 2 3',
#  '6th every day 2 weeks 1 2 3 4 5 6',
#  'several thousand',
#  'first',
#  'ga first',
#  '',
#  'ga ga two one one second roughly half',
#  '',
#  'ga',
#  '',
#  '',
#  '',
#  '5 ga',
#  '',
#  'one',
#  'degrees social sciences one one hours associate year ago first months',
#  '',
#  'one',
#  'ga',
#  '',
#  '',
#  '6 bla bla first one 6 first days one',
#  'ga 10mil ga 0 rest month',
#  'first 23 creating month ago today today first',
#  'one seoadwords',
#  '2 many years ago one 650month seo google',
#  'google',
#  'ga',
#  '3090 ibm',
#  '68th two',
#  'first 5 1 2 3 quote least 5 first week intro',
#  'couple months ago 80 90 three years ago',
#  '',
#  '2 one one first first second second first english',
#  '',
#  '',
#  'year year 33 85 two one one',
#  '',
#  '',
#  'one',
#  'ga dimension1 metric1 1 ga',
#  '',
#  'year two 2 calc2 one phd sql tableau',
#  '',
#  '',
#  'one 10 ga ga',
#  '100 2 days 570 google 100 15',
#  'google',
#  '',
#  'ga',
#  'february 1 monday one two one',
#  '',
#  '',
#  '',
#  '4 8090',
#  '',
#  '',
#  'ga 17 500 22',
#  'datareactidxxgtenrolledltoptiongt ltoption',
#  '100k visitsday last month ga 78k today wp jetpack shows 4000',
#  'seo sem 34 past 56 years 2 years 1215 last month 32 year year 25 1 41 one last year last year last year seo',
#  '2',
#  '',
#  '',
#  '',
#  '',
#  'ga',
#  '11',
#  'last 7 years first today one',
#  'last week',
#  'one ga',
#  '',
#  'ga hong kong 86 34 9627 hong kong 373 34 9627 hong kong google hong kong hong kong 2nd 115 60km37 miles hong kong',
#  '3000 34 google zero 200 month 500 ga ga',
#  '',
#  'ga google',
#  'example google',
#  'google',
#  '',
#  '',
#  '197',
#  'first two 1 2',
#  'ga zero seconds seconds',
#  '',
#  '',
#  'first',
#  '',
#  'domainorg plus subdomaindomainorg client today one 0',
#  'one',
#  'thai tofu thai keyword keyword keyword z',
#  'info ga',
#  'january 74 16 neigh ga',
#  '1 ga ga 2',
#  'new york new york',
#  'second 2 hours',
#  'third third',
#  'google googlefr googlees 62',
#  'one google',
#  'two 0 100 5912 7227 13039 10508 12668 17775 9251 1 2',
#  'first',
#  '2 months ago hundreds thousands ga mobile apps',
#  '',
#  'ga yesterday one ga two',
#  'california 52k 5k year',
#  'google one 1 ec el campaign cs backoffice cm cd5 z cd6 1 ec el campaign cs backoffice cm dl dt',
#  'morning one geo gt location',
#  'andy segment',
#  'ga',
#  '',
#  '',
#  'andy segment',
#  '25 second',
#  'ga',
#  '100 424 8 5 1 1 1 1',
#  'google',
#  'google',
#  'quarterly',
#  'two 18 months yesterday seo data first two one',
#  '',
#  '',
#  '',
#  'gotten google',
#  '20',
#  'ga two',
#  'ga',
#  'google ga chicago 2014 degree 25 year old',
#  '',
#  'two',
#  'one hours',
#  'feb 15',
#  'google linkedincomlnkdin',
#  '',
#  ...]

# %%
vectorizer = CountVectorizer(max_features=5000)  
X = vectorizer.fit_transform(all_entities)

# %%
y = df['subreddit']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
y_pred = clf.predict(X_test)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1-Score (Weighted): {f1}")

print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# F1-Score (Weighted): 0.18211966719430864
#
# Classification Report:
#                        precision    recall  f1-score   support
#
#        AskStatistics       0.27      0.28      0.28      9056
#      DataScienceJobs       0.49      0.29      0.36       688
#          MLQuestions       0.08      0.02      0.03      3410
#      MachineLearning       0.23      0.19      0.21     11223
#            analytics       0.34      0.18      0.24      2349
#           artificial       0.12      0.03      0.04      2621
#      computerscience       0.26      0.13      0.17      6712
#       computervision       0.23      0.10      0.14      2925
#                 data       0.52      0.21      0.30       799
#         dataanalysis       0.07      0.02      0.03      1214
#      dataengineering       0.26      0.07      0.11      2467
#          datascience       0.17      0.59      0.26     11168
#   datascienceproject       0.06      0.03      0.04        76
#             datasets       0.21      0.08      0.12      3442
#         deeplearning       0.09      0.03      0.04      2432
#               kaggle       0.21      0.11      0.15       125
# learnmachinelearning       0.23      0.12      0.16      8764
#               rstats       0.23      0.08      0.12      3252
#           statistics       0.22      0.15      0.18      8952
#
#             accuracy                           0.21     81675
#            macro avg       0.23      0.14      0.16     81675
#         weighted avg       0.22      0.21      0.18     81675
